# %%
letters = []

letters.append("A")
letters.append("B")
letters.append("C")

top = letters.pop()

print(letters)
print("Removed: ", top)

top = letters.pop()
print("Removed: ", top)

letters.append("D")
top = letters.pop()
print("Removed: ", top)

print(letters)

# %%
numbers = []

numbers.append(1)
numbers.append(2)
numbers.append(3)
numbers.append(4)

print(numbers[-1])

# %%
stack = []

stack.append('H')
stack.append('E')
stack.append('L')
stack.append('L')
stack.append('O')

print(stack.reverse)

# %%
word = "Hello"
stack = []
reversed_word = ""
for letter in word:
    stack.append(letter)
while stack:
        reversed_word += stack.pop
    
print(reversed_word)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 9
#       5     stack.append(letter)
#       7 reversed_word = ""
# ----> 9 while not stack.is_empty():
#      10     reversed_word += stack.pop
#      12 print(reversed_word)
#
# AttributeError: 'list' object has no attribute 'is_empty'

# %%
stack = []

# %%
stack = []

if len(stack) == 0:
    print("the stack is empty")
else:
    print("The stack has items")
